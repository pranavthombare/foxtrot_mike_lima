# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator

import pandas as pd
import os
import csv
import requests
import sys
myPath = 'data/images/train/'
# Out:
# Using TensorFlow backend.

# %%
classifier = Sequential()
classifier.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))
classifier.add(Flatten())
classifier.add(Dense(units = 128, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0718 17:19:40.885198 4506512704 deprecation_wrapper.py:119] From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0718 17:19:40.919731 4506512704 deprecation_wrapper.py:119] From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0718 17:19:40.923553 4506512704 deprecation_wrapper.py:119] From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0718 17:19:40.955194 4506512704 deprecation_wrapper.py:119] From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0718 17:19:41.034043 4506512704 deprecation_wrapper.py:119] From /usr/local/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0718 17:19:41.083194 4506512704 deprecation_wrapper.py:119] From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0718 17:19:41.102112 4506512704 deprecation.py:323] From /Users/pranavthombare/Library/Python/3.7/lib/python/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
df=pd.read_csv("data/test.csv")

#then we see how many groups we have
df_class=df.groupby('class')

# %%
zipper_ds = df.loc[df["class"] == "zipper"]
backstrap_ds = df.loc[df["class"] == "backstrap"]
slip_on_ds = df.loc[df["class"] == "slip_on"]
lace_up_ds = df.loc[df["class"] == "lace_up"]
buckle_ds = df.loc[df["class"] == "buckle"]
hook_n_look_ds = df.loc[df["class"] == "hook&look"]

# %%
buckle_ds
# Out:
#                                         id  \
# 1713  4534cf1050574d318f481ed99dff47a7.jpg
# 1714  8ff9cdb7581f4349b0208d5e3ec6dc94.jpg
# 1715  b3f3bd91bb214880a3a9dd63005cb97f.jpg
# 1716  022e5e376d6e496180f2c9bf1515692e.jpg
# 1717  4aa3b72b950d49a1a04977dfb3a56040.jpg
# 1718  04207a009b9547b2ae26f493b3688c18.jpg
# 1719  0a95e76aff9846d5b4efc05fe9443c48.jpg
# 1720  61ab6714e1bd4b58848db4e072b235ba.jpg
# 1721  d9fd8f2931894a6c96e3680c64b1f025.jpg
# 1722  920edd6de99840eea8a5a0317a18cc82.jpg
# 1723  37a7fefb63e94b82affeec10ab18d217.jpg
# 1724  b8e9290393a043ddbd909e88867e8d3d.jpg
# 1725  f0d6437d354f4a33afc219c1d93f9d7e.jpg
# 1726  941a2f8b1fd94089ba64bf98d7c98187.jpg
# 1727  754419cb1cdd4dcaac72aaf380d59edf.jpg
# 1728  406b87edd3ae473f84b503c28f705192.jpg
# 1729  03b8bd2a34ac46d995e6b9bc41a6ce9b.jpg
# 1730  07a64615fb5548f7b4301140647fd32c.jpg
# 1731  9bae0396188f4185a2a13883688236ab.jpg
# 1732  859ad695f6864332b36e5423dbfe3ed2.jpg
# 1733  2357190af2094d69b743ee54b08c1345.jpg
# 1734  dfc7ed892f374da1824b68f62fb1ae41.jpg
# 1735  1ec0b38934fa42459196121799c440d9.jpg
# 1736  8cf9c2a127b54c6bb0257ea9c261232a.jpg
# 1737  8373570329fd4ffeacbafb826df645cf.jpg
# 1738  33c545585f5a40e5ae3b96c1a3c4a4f6.jpg
# 1739  d06280713a9c4596bb7039e08aa4a021.jpg
# 1740  eafff92bfe894dbab1910526788ffc73.jpg
# 1741  5ec1495861b5482c8784c272514f77ef.jpg
# 1742  2ecded55483644f794922e4b3bd3385e.jpg
# ...                                    ...
# 1822  bcbc6b4343274cc6a211edfb9da2e362.jpg
# 1823  e308ba06b43443f29ef098dcf8ee3a61.jpg
# 1824  08bb27c35e1f4ccebbe8eacac48aa806.jpg
# 1825  632356a3f0a3448797696497cf695477.jpg
# 1826  402f31787e6044b5ba8cd29febaf2e91.jpg
https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1718  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1719  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1720  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1721  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1722  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1723  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1724  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1725  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1726  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1727  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1728  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1729  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1730  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1731  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1732  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1733  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1734  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1735  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1736  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1737  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1738  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1739  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1740  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1741  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1742  https://vision-images-store.s3.amazonaws.com/i...  buckle
# ...                                                 ...     ...
# 1822  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1823  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1824  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1825                                                NaN  buckle
# 1826  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1827  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1828  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1829  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1830  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1831  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1832  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1833  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1834  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1835  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1836  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1837  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1838  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1839  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1840  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1841  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1842  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1843  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1844  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1845  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1846  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1847  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1848  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1849  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1850  https://vision-images-store.s3.amazonaws.com/i...  buckle
# 1851  https://vision-images-store.s3.amazonaws.com/i...  buckle
#
# [139 rows x 7 columns]

# %%
for col in backstrap_ds.columns:
    j=500
    if col == 'view_1':
            temp_ds_1 = backstrap_ds['view_1']
            while j < 835 :
                url_1 = temp_ds_1[j]                
                filename = "backstrap/image_" + str(j) + "_view_1" +".jpg"
                fullfilename = os.path.join(myPath, filename)
                r = requests.get(url_1, allow_redirects=True)
                open(fullfilename, 'wb').write(r.content)
                print(str(j)+ " images")
                j = j+1
print('completed downloading')

# %%
for col in slip_on_ds.columns:
    j=835
    if col == 'view_1':
            temp_ds2 = slip_on_ds['view_1']
            while j < 1260 :
                url2 = temp_ds2[j]                
                filename = "slip_on/image_" + str(j) + "_view_1" +".jpg"
                fullfilename = os.path.join(myPath, filename)
                r2 = requests.get(ur2l, allow_redirects=True)
                open(fullfilename, 'wb').write(r2.content)
                print(str(j)+ " images")
                j = j+1
print('completed downloading')

# %%
for col in lace_up_ds.columns:
    j=1260
    if col == 'view_1':
            temp_ds = lace_up_ds['view_1']
            while j < 1712:
                url = temp_ds[j]                
                filename = "lace_up/image_" + str(j) + "_view_1" +".jpg"
                fullfilename = os.path.join(myPath, filename)
                r = requests.get(url, allow_redirects=True)
                open(fullfilename, 'wb').write(r.content)
                print(str(j)+ " images")
                j = j+1
print('completed downloading')

# %%
for col in buckle_ds.columns:
    j=1712
    if col == 'view_1':
            temp_ds3 = buckle_ds['view_1']
            while j < 1852 :
                url3 = temp_ds3[j]                
                filename = "buckle/image_" + str(j) + "_view_1" +".jpg"
                fullfilename = os.path.join(myPath, filename)
                r3 = requests.get(url3, allow_redirects=True)
                open(fullfilename, 'wb').write(r3.content)
                print(str(j)+ " images")
                j = j+1
print('completed downloading')

# %%
for col in hook_n_look_ds.columns:
    j=1852
    if col == 'view_1':
            temp_ds4 = hook_n_look_ds['view_1']
            while j < 2155 :
                url4 = temp_ds4[j]                
                filename = "hook_n_look/image_" + str(j) + "_view_1" +".jpg"
                fullfilename = os.path.join(myPath, filename)
                r4 = requests.get(url4, allow_redirects=True)
                open(fullfilename, 'wb').write(r4.content)
                print(str(j)+ " images")
                j = j+1
print('completed downloading')

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('data/images/train',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')

test_set = test_datagen.flow_from_directory('data/images/test',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')

classifier.fit_generator(training_set,
                         steps_per_epoch = 8000,
                         epochs = 2,
                         validation_data = test_set,
                         validation_steps = 2000)

classifier.save_weights('first_try.h5')  # always save your weights after training or during training
